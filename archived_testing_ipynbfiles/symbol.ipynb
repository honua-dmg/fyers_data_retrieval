# %%
from data import Depth,Symbol
import time

symbol_access = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....qgo4m2ydF-O7aYfuDq4S9UKmoCGVQtAd4Z0-ecYVCww'
symbol = Symbol(symbol_access,['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ'])
symbol.connect()
symbol.subscribe()
# Out:
# RESPONSE: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# connection opened
# RESPONSE: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}
# RESPONSE: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# RESPONSE: {'ltp': 861.5, 'vol_traded_today': 3898013, 'last_traded_time': 1720762275, 'exch_feed_time': 1720762275, 'bid_size': 84, 'ask_size': 8479, 'bid_price': 861.45, 'ask_price': 861.5, 'last_traded_qty': 135, 'tot_buy_qty': 627677, 'tot_sell_qty': 1789922, 'avg_trade_price': 859.12, 'low_price': 855.3, 'high_price': 861.7, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 856.7, 'prev_close_price': 856.7, 'type': 'sf', 'symbol': 'NSE:SBIN-EQ', 'ch': 4.8, 'chp': 0.5603}
# ...

# %% [markdown]
# # USING MULTIPROCESSING lib

# %%
symbol.unsubscribe()

# %%
sym_auth = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....qgo4m2ydF-O7aYfuDq4S9UKmoCGVQtAd4Z0-ecYVCww'
dep_auth = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....3bWGpqsKP4HPgGecQFjKAV6JihDHfz-SwQNG9rMlTcw'
stonks = ['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ']
wait_time = 20

# %%
import multiprocessing
from data import Depth,Symbol
import time

# %%
def func(Data_class,auth,stonks,wait_time):
    symbol = Data_class(auth,stonks)
    symbol.connect()
    time.sleep(wait_time)
    symbol.subscribe()

# %%
if __name__=="__main__":
    dep = multiprocessing.Process(target = func, args=(Depth,dep_auth,stonks,wait_time))
    sym = multiprocessing.Process(target = func, args=(Symbol,sym_auth,stonks,wait_time))

    dep.start()
    sym.start()

    dep.join()
    sym.join()
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/spawn.py", line 122, in spawn_main
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/spawn.py", line 122, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#     exitcode = _main(fd, parent_sentinel)
#                         ^ ^ ^ ^ ^ ^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/spawn.py", line 132, in _main
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/spawn.py", line 132, in _main
#     self = reduction.pickle.load(from_parent)
#     self = reduction.pickle.load(from_parent)
#            ^^^^^^^^^^^     ^^^^^^ ^ ^ ^ ^ ^ ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ^^^^AttributeError^^: ^Can't get attribute 'func' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
# ^^^^^^^^^
# ...

# %%
import multiprocessing
from data import Depth,Symbol, func
import time
sym_auth = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....qgo4m2ydF-O7aYfuDq4S9UKmoCGVQtAd4Z0-ecYVCww'
dep_auth = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....3bWGpqsKP4HPgGecQFjKAV6JihDHfz-SwQNG9rMlTcw'
stonks = ['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ']
wait_time = 60

# %%
if __name__=="__main__":
    dep = multiprocessing.Process(target = func, args=(Depth,dep_auth,stonks,wait_time))
    sym = multiprocessing.Process(target = func, args=(Symbol,sym_auth,stonks,wait_time))

    dep.start()
    sym.start()

    dep.join()
    sym.join()
# Out:
# RESPONSE: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# Response: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# connection opened
# connection opened
# Response: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}
# RESPONSE: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}
# RESPONSE: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# Response: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# RESPONSE: {'ltp': 859.35, 'vol_traded_today': 7702414, 'last_traded_time': 1720772640, 'exch_feed_time': 1720772640, 'bid_size': 59, 'ask_size': 127, 'bid_price': 859.1, 'ask_price': 859.35, 'last_traded_qty': 90, 'tot_buy_qty': 642309, 'tot_sell_qty': 1787829, 'avg_trade_price': 859.59, 'low_price': 855.3, 'high_price': 863.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 856.7, 'prev_close_price': 856.7, 'type': 'sf', 'symbol': 'NSE:SBIN-EQ', 'ch': 2.65, 'chp': 0.3093}
# ...
