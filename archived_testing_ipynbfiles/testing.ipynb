# %%
TOTPtoken='J7FQH2SSSFM73FCKJBPADBZ7OFB6BNES'
key='7845'
phonenumber='7013036199'
client_id1 = "7QYRMB1P75-100"
secret_key1 = "ZOO1C73JLJ"
redirect_uri1 = "https://www.google.com/"

client_id2 = "ED5OZI8YV6-100"
secret_key2 = "WDJIPBAUV0"
redirect_uri2 = 'https://www.google.com/'

# %%
from accesstoken import Initial
from data import Depth,Symbol

# %%
symbol_access = Initial(client_id=client_id1,
                        secret_key=secret_key1,
                        redirect_uri=redirect_uri1,
                        TOTPseckey=TOTPtoken,
                        key=key,
                        phoneno=phonenumber).get_access_token()
depth_access = Initial(client_id=client_id2,
                        secret_key=secret_key2,
                        redirect_uri=redirect_uri2,
                        TOTPseckey=TOTPtoken,
                        key=key,
                        phoneno=phonenumber).get_access_token()
# Out:
# no neeed to validate :)
# 200
# ********************************************************************************
# success
# no neeed to validate :)
# 200
# ********************************************************************************
# success

# %%
symbol_access
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....XkKx8VcIvFu2yPAY2WeC_vYHJ1f3KSrcnmneVbjUVv4'

# %%
depth_access
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....QypnBnF9c5MEWCWnYB7V6HzuR5o9R0UM9SHAKozNmoY'

# %%
depth = Depth(access_token=symbol_access,stonks=['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ'])

# %%
depth.connect()
# Out:
# Response: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# connection opened
# Response: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}

# %%
depth.subscribe()
# Out:
# Response: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# Response: {'bid_price1': 850.55, 'bid_price2': 850.5, 'bid_price3': 850.45, 'bid_price4': 850.4, 'bid_price5': 850.35, 'ask_price1': 850.95, 'ask_price2': 851.0, 'ask_price3': 851.05, 'ask_price4': 851.1, 'ask_price5': 851.15, 'bid_size1': 450, 'bid_size2': 681, 'bid_size3': 449, 'bid_size4': 940, 'bid_size5': 854, 'ask_size1': 403, 'ask_size2': 1077, 'ask_size3': 981, 'ask_size4': 549, 'ask_size5': 1024, 'bid_order1': 4, 'bid_order2': 5, 'bid_order3': 4, 'bid_order4': 14, 'bid_order5': 9, 'ask_order1': 6, 'ask_order2': 13, 'ask_order3': 6, 'ask_order4': 10, 'ask_order5': 9, 'type': 'dp', 'symbol': 'NSE:SBIN-EQ'}
# ...

# %%
creds = Symbol(access_token=symbol_access,stonks=['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ'])

# %%
creds.connect()
# Out:
# Response: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# connection opened
# Response: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}

# %%
creds.subscribe()
# Out:
# Response: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# Response: {'ltp': 852.3, 'vol_traded_today': 9474886, 'last_traded_time': 1720594791, 'exch_feed_time': 1720594792, 'bid_size': 37, 'ask_size': 219, 'bid_price': 852.15, 'ask_price': 852.3, 'last_traded_qty': 3, 'tot_buy_qty': 835903, 'tot_sell_qty': 1601972, 'avg_trade_price': 851.6, 'low_price': 843.5, 'high_price': 860.25, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 860.1, 'prev_close_price': 861.3, 'type': 'sf', 'symbol': 'NSE:SBIN-EQ', 'ch': -9.0, 'chp': -1.0449}
# ...

# %%
creds.unsubscribe()
# Out:
# Response: {'ltp': 1000.85, 'vol_traded_today': 8004818, 'last_traded_time': 1720591144, 'exch_feed_time': 1720591145, 'bid_size': 1, 'ask_size': 9, 'bid_price': 1000.65, 'ask_price': 1000.85, 'last_traded_qty': 2, 'tot_buy_qty': 545647, 'tot_sell_qty': 1516985, 'avg_trade_price': 1007.63, 'low_price': 986.05, 'high_price': 1019.85, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 1015.0, 'prev_close_price': 1014.95, 'type': 1, 'symbol': 1, 'ch': -14.1, 'chp': -1.3892}
# Error: 'int' object is not iterable
# Response: {'ltp': 849.6, 'vol_traded_today': 293885, 'last_traded_time': 1720591140, 'exch_feed_time': 1720591147, 'bid_size': 97, 'ask_size': 244, 'bid_price': 849.6, 'ask_price': 850.0, 'last_traded_qty': 1, 'tot_buy_qty': 130575, 'tot_sell_qty': 155403, 'avg_trade_price': 850.56, 'low_price': 843.3, 'high_price': 861.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 861.0, 'prev_close_price': 860.95, 'type': 2, 'symbol': 7, 'ch': -11.35, 'chp': -1.3183}
# ...

# %%
creds.unsubscribe()
# Out:
# Response: {'ltp': 1005.75, 'vol_traded_today': 9418454, 'last_traded_time': 1720594835, 'exch_feed_time': 1720594835, 'bid_size': 1, 'ask_size': 4, 'bid_price': 1005.6, 'ask_price': 1005.75, 'last_traded_qty': 30, 'tot_buy_qty': 595803, 'tot_sell_qty': 1597489, 'avg_trade_price': 1007.33, 'low_price': 986.05, 'high_price': 1019.85, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 1015.0, 'prev_close_price': 1014.95, 'type': 'sf', 'symbol': 'NSE:TATAMOTORS-EQ', 'ch': -9.2, 'chp': -0.9064}
# Response: {'ltp': 852.45, 'vol_traded_today': 332526, 'last_traded_time': 1720594834, 'exch_feed_time': 1720594836, 'bid_size': 214, 'ask_size': 42, 'bid_price': 852.0, 'ask_price': 852.45, 'last_traded_qty': 2, 'tot_buy_qty': 137900, 'tot_sell_qty': 158041, 'avg_trade_price': 850.68, 'low_price': 843.3, 'high_price': 861.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 861.0, 'prev_close_price': 860.95, 'type': 'sf', 'symbol': 'BSE:SBIN-A', 'ch': -8.5, 'chp': -0.9873}
# ...

# %%
depth_access
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....fv0tCk60rG6AAPRfvUqyE6hyREDkfroGclHo2kaGyHE'

# %%
symbol_access
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....kt93DHSNpAYMGLaic1E1V5Kbdwthco0gRO_aZV9IsCs'

# %%
test = Symbol('lalala',['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ'])

# %%
test.save_files(message={'ltp': 846.4, 'vol_traded_today': 193721, 'last_traded_time': 1720588528, 'exch_feed_time': 1720588531, 'bid_size': 1, 'ask_size': 216, 'bid_price': 846.0, 'ask_price': 846.4, 'last_traded_qty': 3, 'tot_buy_qty': 117752, 'tot_sell_qty': 164141, 'avg_trade_price': 851.01, 'low_price': 843.3, 'high_price': 861.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 861.0, 'prev_close_price': 860.95, 'type': 1, 'symbol': 1, 'ch': -14.55, 'chp': -1.69}
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 test.save_files(message={'ltp': 846.4, 'vol_traded_today': 193721, 'last_traded_time': 1720588528, 'exch_feed_time': 1720588531, 'bid_size': 1, 'ask_size': 216, 'bid_price': 846.0, 'ask_price': 846.4, 'last_traded_qty': 3, 'tot_buy_qty': 117752, 'tot_sell_qty': 164141, 'avg_trade_price': 851.01, 'low_price': 843.3, 'high_price': 861.0, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 861.0, 'prev_close_price': 860.95, 'type': 1, 'symbol': 1, 'ch': -14.55, 'chp': -1.69}
#       2 )
#
# File ~/programming/STONKS/ARBRITRAGE/Data_retreival/data.py:87, in _Data.save_files(self, message)
#      84     return
#      86 del message['type'] # we don't need it
# ---> 87 file_symbol = ''.join(['-' if x == ":" else x for x in message.pop('symbol')])
# ...

# %%
response = Initial(client_id=client_id2,secret_key=secret_key2,redirect_uri=redirect_uri2,).get_response()

# %%
response
# Out:
# 'https://api-t1.fyers.in/api/v3/generate-authcode?client_id=ED5OZI8YV6-100&redirect_uri=https%3A%2F%2Fwww.google.com%2F&response_type=code&state=None'

# %%
from data import Depth,Symbol
import time

depth_access = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....QypnBnF9c5MEWCWnYB7V6HzuR5o9R0UM9SHAKozNmoY'

depth = Depth(depth_access,['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ'])


depth.connect()


depth.subscribe()


time.sleep(10)
depth.unsubscribe()
# Out:
# Response: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# connection opened
# Response: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}
# Response: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# Response: {'bid_price1': 848.55, 'bid_price2': 848.4, 'bid_price3': 848.35, 'bid_price4': 848.3, 'bid_price5': 848.25, 'ask_price1': 848.65, 'ask_price2': 848.75, 'ask_price3': 848.8, 'ask_price4': 848.85, 'ask_price5': 848.9, 'bid_size1': 2, 'bid_size2': 282, 'bid_size3': 877, 'bid_size4': 1748, 'bid_size5': 1431, 'ask_size1': 213, 'ask_size2': 287, 'ask_size3': 614, 'ask_size4': 846, 'ask_size5': 812, 'bid_order1': 1, 'bid_order2': 5, 'bid_order3': 10, 'bid_order4': 14, 'bid_order5': 14, 'ask_order1': 3, 'ask_order2': 3, 'ask_order3': 6, 'ask_order4': 7, 'ask_order5': 9, 'type': 'dp', 'symbol': 'NSE:SBIN-EQ'}
# ...

# %%
import concurrent.futures

from data import Depth,Symbol
import time
def process(type,auth_code,stonks,wait_time):
    access = auth_code
    data = type(access,stonks)
    data.connect()
    data.subscribe()
    time.sleep(wait_time)
    data.unsubscribe()


with concurrent.futures.ProcessPoolExecutor() as exec:
    dep = exec.submit(process,[Depth,
                        'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....QypnBnF9c5MEWCWnYB7V6HzuR5o9R0UM9SHAKozNmoY',
                        ['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ'],
                        10])
    symb = exec.submit(process,[Symbol,
                        'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....XkKx8VcIvFu2yPAY2WeC_vYHJ1f3KSrcnmneVbjUVv4',
                        ['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ'],
                        10])
# Out:
# Process SpawnProcess-6:
# Process SpawnProcess-5:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/concurrent/futures/process.py", line 251, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: Can't get attribute 'process' on <module '__main__' (<class '_frozen_importlib.BuiltinImporter'>)>
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# ...

# %%
with concurrent.futures.ProcessPoolExecutor() as exec:
    dep = exec.submit(process,[Depth,
                        'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....QypnBnF9c5MEWCWnYB7V6HzuR5o9R0UM9SHAKozNmoY',
                        ['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ'],
                        10])
    symb = exec.submit(process,[Symbol,
                        'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....XkKx8VcIvFu2yPAY2WeC_vYHJ1f3KSrcnmneVbjUVv4',
                        ['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ'],
                        10])
# Out:
# Process SpawnProcess-4:
# Process SpawnProcess-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/concurrent/futures/process.py", line 251, in _process_worker
#     call_item = call_queue.get(block=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
import threading
from data import Depth,Symbol
import time
def process(class_type,auth_code,stonks,wait_time):
    access = auth_code
    data = class_type(access,stonks)
    data.connect()
    data.subscribe()
    time.sleep(wait_time)
    data.unsubscribe()
dep_auth = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....3bWGpqsKP4HPgGecQFjKAV6JihDHfz-SwQNG9rMlTcw'
stonks = ['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ']
wait_time = 20
dep_thread = threading.Thread(target=process, args=(Depth, dep_auth, stonks, wait_time))
symb_thread = threading.Thread(target=process, args=(Symbol, sym_auth, stonks, wait_time))
dep_thread.start()
symb_thread.start()
# Out:
# RESPONSE: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# connection openedconnection opened
#
# RESPONSE: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}
# RESPONSE: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# RESPONSE: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# RESPONSE: {'ltp': 857.9, 'vol_traded_today': 3130423, 'last_traded_time': 1720761540, 'exch_feed_time': 1720761541, 'bid_size': 30, 'ask_size': 41, 'bid_price': 858.05, 'ask_price': 858.1, 'last_traded_qty': 236, 'tot_buy_qty': 660819, 'tot_sell_qty': 1894578, 'avg_trade_price': 859.02, 'low_price': 855.3, 'high_price': 861.7, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 856.7, 'prev_close_price': 856.7, 'type': 'sf', 'symbol': 'NSE:SBIN-EQ', 'ch': 1.2, 'chp': 0.1401}
# ...

# %%
process(Symbol, sym_auth, stonks, wait_time)
# Out:
# RESPONSE: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# connection opened
# RESPONSE: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}
# RESPONSE: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# RESPONSE: {'ltp': 848.65, 'vol_traded_today': 13477881, 'last_traded_time': 1720603820, 'exch_feed_time': 1720603820, 'bid_size': 42, 'ask_size': 4, 'bid_price': 848.55, 'ask_price': 848.65, 'last_traded_qty': 6, 'tot_buy_qty': 798691, 'tot_sell_qty': 1689349, 'avg_trade_price': 850.68, 'low_price': 843.5, 'high_price': 860.25, 'lower_ckt': 0, 'upper_ckt': 0, 'open_price': 860.1, 'prev_close_price': 861.3, 'type': 'sf', 'symbol': 'NSE:SBIN-EQ', 'ch': -12.65, 'chp': -1.4687}
# ...

# %%
creds = {}
depth = {}
with open('secrets.txt','r') as f:
    txt = f.readlines()
    for i in range(len(txt)):
        if 'symbol' in txt[i]:
            creds['TOTPseckey'] = txt[i+1].split('=')[1].strip("\n,")
            creds['key'] = txt[i+2].split('=')[1].strip("\n,")
            creds['phoneno'] = txt[i+3].split('=')[1].strip("\n,")
            creds['client_id'] = txt[i+4].split('=')[1].strip("\n,")
            creds['secret_key'] = txt[i+5].split('=')[1].strip("\n,")
            creds['redirect_uri'] = txt[i+6].split('=')[1].strip("\n,")  
    
        
        """
        if 'symbol' in line:
            f.readline()
            symbol['TOTPseckey'] = f.readline().split('=')[1].strip('"')
            symbol['key'] = f.readline().split('=')[1].strip('"')
            symbol['phoneno'] = f.readline().split('=')[1].strip('"')
            symbol['client_id'] = f.readline().split('=')[1].strip('"')
            symbol['secret_key'] = f.readline().split('=')[1].strip('"')
            symbol['redirect_uri'] = f.readline().split('=')[1].strip('"')        
        if 'depth' in line:
            f.readline()
            depth['TOTPseckey'] = f.readline().split('=')[1].strip('"')
            depth['key'] = f.readline().split('=')[1].strip('"')
            depth['phoneno'] = f.readline().split('=')[1].strip('"')
            depth['client_id'] = f.readline().split('=')[1].strip('"')
            depth['secret_key'] = f.readline().split('=')[1].strip('"')
            depth['redirect_uri'] = f.readline().split('=')[1].strip('"')"""

# %%
creds
# Out:
# {'TOTPseckey': 'J7FQH2SSSFM73FCKJBPADBZ7OFB6BNES',
#  'key': '7845',
#  'phoneno': '7013036199',
#  'client_id': '7QYRMB1P75-100',
#  'secret_key': 'ZOO1C73JLJ',
#  'redirect_uri': 'https://www.google.com/'}

# %%
def get_creds(file_loc,data_type):
    creds = {}
    with open(file_loc,'r') as f:
        txt = f.readlines()
        for i in range(len(txt)):
            if data_type in txt[i]:
                creds['TOTPseckey'] = txt[i+1].split('=')[1].strip("\n,")
                creds['key'] = txt[i+2].split('=')[1].strip("\n,")
                creds['phoneno'] = txt[i+3].split('=')[1].strip("\n,")
                creds['client_id'] = txt[i+4].split('=')[1].strip("\n,")
                creds['secret_key'] = txt[i+5].split('=')[1].strip("\n,")
                creds['redirect_uri'] = txt[i+6].split('=')[1].strip("\n,")  
    return creds

# %%
symbol = get_creds('secrets.txt','symbol')

# %%
# Out:
# {'TOTPseckey': 'J7FQH2SSSFM73FCKJBPADBZ7OFB6BNES',
#  'key': '7845',
#  'phoneno': '7013036199',
#  'client_id': '7QYRMB1P75-100',
#  'secret_key': 'ZOO1C73JLJ',
#  'redirect_uri': 'https://www.google.com/'}

# %%
import accesstoken

# %%
symb = accesstoken.AutoLogin('secrets.txt','symbol')

# %%
dep_auth = accesstoken.AutoLogin('secrets.txt','depth').get_access_token()
# Out:
# no neeed to validate :)
# 200
# ********************************************************************************
# success

# %%
sym_auth = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....qgo4m2ydF-O7aYfuDq4S9UKmoCGVQtAd4Z0-ecYVCww'
dep_auth = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....3bWGpqsKP4HPgGecQFjKAV6JihDHfz-SwQNG9rMlTcw'

# %%
dep_auth
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....3bWGpqsKP4HPgGecQFjKAV6JihDHfz-SwQNG9rMlTcw'

# %%
from data import Depth,Symbol
import time
data = Depth(dep_auth,stonks)
data.connect()
data.subscribe()
time.sleep(100)
data.unsubscribe()
dep_auth = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....3bWGpqsKP4HPgGecQFjKAV6JihDHfz-SwQNG9rMlTcw'
stonks = ['NSE:SBIN-EQ','BSE:SBIN-A','NSE:TATAMOTORS-EQ']
# Out:
# Response: {'type': 'cn', 'code': 200, 'message': 'Authentication done', 's': 'ok'}
# connection opened
# Response: {'type': 'ful', 'code': 200, 'message': 'Full Mode On', 's': 'ok'}
# Response: {'type': 'unsub', 'code': 200, 'message': 'Unsubscribed', 's': 'ok'}
# Response: {'type': 'sub', 'code': 200, 'message': 'Subscribed', 's': 'ok'}
# Response: {'bid_price1': 859.95, 'bid_price2': 859.9, 'bid_price3': 859.85, 'bid_price4': 859.8, 'bid_price5': 859.75, 'ask_price1': 860.25, 'ask_price2': 860.3, 'ask_price3': 860.35, 'ask_price4': 860.4, 'ask_price5': 860.45, 'bid_size1': 210, 'bid_size2': 338, 'bid_size3': 573, 'bid_size4': 568, 'bid_size5': 561, 'ask_size1': 113, 'ask_size2': 678, 'ask_size3': 245, 'ask_size4': 2383, 'ask_size5': 1588, 'bid_order1': 4, 'bid_order2': 4, 'bid_order3': 7, 'bid_order4': 8, 'bid_order5': 6, 'ask_order1': 2, 'ask_order2': 3, 'ask_order3': 5, 'ask_order4': 10, 'ask_order5': 8, 'type': 'dp', 'symbol': 'SBIN-EQ'}
# ...
